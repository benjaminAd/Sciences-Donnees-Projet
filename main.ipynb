# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
datas = pd.read_csv("datas.csv")

# %%
datas
# Out:
#     Unnamed: 0  claimReview_author claimReview_author_name  \
# 0            0                 NaN                  snopes
# 1            1                 NaN                  snopes
# 2            2                 NaN                  snopes
# 3            3                 NaN                  snopes
# 4            4                 NaN                  snopes
# ..         ...                 ...                     ...
# 63          63                 NaN                  snopes
# 64          64                 NaN                  snopes
# 65          65                 NaN                  snopes
# 66          66                 NaN                  snopes
# 67          67                 NaN                  snopes
#
#     claimReview_author_url                          claimReview_claimReviewed  \
# 0                      NaN  Finnish President Sauli Niinistö posted a vide...
# 1                      NaN  A supporter of U.S. Rep. Alexandria Ocasio-Cor...
# ...

# %%
datas.loc[2]
# Out:
# Unnamed: 0                                                                                  2
# claimReview_author                                                                        NaN
# claimReview_author_name                                                                snopes
# claimReview_author_url                                                                    NaN
# claimReview_claimReviewed                   A photograph shows a bride and groom during a ...
# claimReview_datePublished                                                          2019-10-04
# claimReview_source                                                                     snopes
# claimReview_url                             https://www.snopes.com/fact-check/handmaid-tal...
# creativeWork_author_name                                                                  NaN
# creativeWork_author_sameAs                                                                NaN
# ...
